# %%
# Load CSV using Pandas as a pandas.DataFrame
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
    
from pandas import read_csv
filename = 'project.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
data = read_csv(filename, names=names)
print(data.shape)
# Out:
# (17712, 9)

# %%
from pandas import read_csv
filename = "project.csv"
names = ['to_rating', 'to_count', 'audi_rating', 'audi_count', 'to_top_count', 'to_fresh_count', 'to_rotten_count'] 
data = read_csv(filename, names=names)
peek = data.head(25)
print(peek)
# Out:
#     to_rating  to_count  audi_rating  audi_count  to_top_count  \
# 0        49.0     149.0         53.0    254421.0            43
# 1        87.0     142.0         64.0     11574.0            44
# 2        67.0      24.0         53.0     14684.0             2
# 3       100.0      54.0         97.0    105386.0             6
# 4        89.0      27.0         74.0     68918.0             5
# 5         8.0     149.0         37.0    411140.0            37
# 6        96.0      51.0         86.0     23890.0             8
# 7        96.0      28.0         79.0      9243.0             6
# 8        20.0      10.0         87.0      4819.0             0
# 9        82.0      11.0         40.0       457.0             4
# 10       80.0      15.0         66.0     21475.0             3
# 11       91.0      22.0         79.0     20821.0             1
# 12       25.0      83.0         64.0     25944.0            37
# 13      100.0      10.0         86.0       335.0             1
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

movies = pd.read_excel('movies.xlsx')
movies.head()
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# ...

# %%
movies = movies[['movie_title','content_rating','genres','original_release_date','tomatometer_status','tomatometer_rating','tomatometer_count','audience_status','audience_rating','audience_count','tomatometer_top_critics_count','tomatometer_fresh_critics_count','tomatometer_rotten_critics_count']]
movies.columns
# Out:
# Index(['movie_title', 'content_rating', 'genres', 'original_release_date',
#        'tomatometer_status', 'tomatometer_rating', 'tomatometer_count',
#        'audience_status', 'audience_rating', 'audience_count',
#        'tomatometer_top_critics_count', 'tomatometer_fresh_critics_count',
#        'tomatometer_rotten_critics_count'],
#       dtype='object')

# %%
movies.sort_values(by=['tomatometer_rating', 'content_rating'],
ascending=[True, False]).head()
# Out:
#             movie_title content_rating                             genres  \
# 24                Whore              R   Art House & International, Drama
# 29   Going the Distance              R                             Comedy
# 118               House              R  Drama, Horror, Mystery & Suspense
# 195                Scar              R  Drama, Horror, Mystery & Suspense
# 285              Stolen              R          Drama, Mystery & Suspense
#
#     original_release_date tomatometer_status  tomatometer_rating  \
# 24             2004-04-16             Rotten                 0.0
# 29             2004-08-20             Rotten                 0.0
# 118            2008-11-07             Rotten                 0.0
# 195            2007-05-20             Rotten                 0.0
# 285            2010-03-05             Rotten                 0.0
#
#      tomatometer_count audience_status  audience_rating  audience_count  \
# ...

# %%
movies_grouped = movies.groupby('genres')
movies_grouped

# %%
movies_grouped[['tomatometer_rating','audience_rating',]].mean()
# Out:
#                                                     tomatometer_rating  \
# genres
# Action & Adventure                                           36.965686
# Action & Adventure, Animation                                81.850000
# Action & Adventure, Animation, Anime & Manga, A...           80.000000
# Action & Adventure, Animation, Anime & Manga, A...           60.333333
# Action & Adventure, Animation, Anime & Manga, D...           82.000000
# ...                                                                ...
# Science Fiction & Fantasy, Special Interest                  94.000000
# Science Fiction & Fantasy, Western                           88.000000
# Special Interest                                             83.333333
# Television                                                   36.000000
# Western                                                      65.000000
#
#                                                     audience_rating
# genres
# ...

# %%
movies_grouped = movies.groupby('content_rating')
movies_grouped

# %%
movies_grouped[['tomatometer_rating','audience_rating',]].mean()
# Out:
#                 tomatometer_rating  audience_rating
# content_rating
# G                        69.446746        68.210059
# NC17                     68.526316        66.631579
# NR                       72.637599        63.807280
# PG                       59.555196        63.006010
# PG-13                    50.129325        59.580808
# R                        55.354753        56.648291
